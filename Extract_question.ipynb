# %%
import pandas as pd

# %%
import pandas as pd
import openpyxl



# Ouvrez le fichier Excel avec openpyxl
wb = openpyxl.load_workbook('Scoring Hôtel2.xlsx')

# Obtenez le nom du premier onglet
premier_onglet = wb.sheetnames[1]

# Fermez le fichier Excel
wb.close()

# Lisez le premier onglet avec pandas
df = pd.read_excel('Scoring Hôtel2.xlsx', sheet_name=premier_onglet, skiprows=7)

# Maintenant, 'df' contient les données du premier onglet en excluant les 7 premières lignes
onglet_a_traiter = premier_onglet

# %%
df
# Out:
#                                                  Texte  Ponderation  \
# 0                                                  NaN          NaN
# 1                           1. Contrôle du Back office          NaN
# 2                                                  NaN          NaN
# 3    Un contrôle du Bac sur un échantillon représen...          3.0
# 4                                                  NaN          NaN
# ..                                                 ...          ...
# 808  En cas de panne informatique prolongée, existe...          3.2
# 809                                                NaN          NaN
# 810                                         Sauvegarde          NaN
# 811                                                NaN          NaN
# 812  Est ce que les sauvegardes réalisées sont sécu...          1.0
#
#                        Risques
# 0                          NaN
# 1                          NaN
# 2                          NaN
# ...

# %%
df = df.iloc[:, [0, 5, 9, 12]]
# Vous pouvez accéder aux données comme suit :
# Par exemple, pour afficher les 5 premières lignes :
df.head(20)
# Out:
#     Pondération                                         Unnamed: 5  \
# 0           NaN                                                NaN
# 1           NaN                         1. Contrôle du Back office
# 2           NaN                                                NaN
# 3           3.0  Un contrôle du Bac sur un échantillon représen...
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           4.0              - Existence de garanties de paiements
# 7           3.0                                 - Tarifs appliqués
# 8           3.0      - Présence des justificatifs Points de Ventes
# 9           3.0             - Visa du client sur les justificatifs
# 10          4.0  - Présence d'une fiche de police pour chaque c...
# 11          NaN                                                NaN
# 12          2.0  Le principe de note à la semaine est-il appliqué?
# ...

# %%
# Initialise une variable pour stocker la valeur du cycle
cycle_actuel = None
nouvelle_colonne_cycle = []

# Crée la nouvelle colonne "Cycle" en se basant sur les colonnes 6 et 9
for index, row in df.iterrows():
    if row[2] == 0:
        # Si la colonne 9 contient un 0, met la valeur de la colonne 6 dans "Cycle"
        cycle_actuel = row[1]
    nouvelle_colonne_cycle.append(cycle_actuel)

# Ajoute la nouvelle colonne "Cycle" au DataFrame
df['Cycle'] = nouvelle_colonne_cycle



# Garde les lignes avec des données dans les cinq colonnes
#df = df.dropna(subset=[df.columns[0], df.columns[5], df.columns[12], df.columns[9], 'Cycle'], how='all')




# Réindexe le DataFrame
#df = df.reset_index(drop=True)

# Enregistre les données mises à jour dans un nouveau fichier Excel
#df.to_excel('nouveau_fichier_excel.xlsx', index=False)
# Out:
# C:\Users\cefim.D352004230014\AppData\Local\Temp\ipykernel_14272\1598962761.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cycle'] = nouvelle_colonne_cycle

# %%
df
# Out:
#      Pondération                                         Unnamed: 5  \
# 0            NaN                                                NaN
# 1            NaN                         1. Contrôle du Back office
# 2            NaN                                                NaN
# 3           3.00  Un contrôle du Bac sur un échantillon représen...
# 4            NaN                                                NaN
# ..           ...                                                ...
# 108         2.75  Pour les remboursement CB, sont ils effectués ...
# 109          NaN                                                NaN
# 110         2.75  Toutes les dérogations aux conditions tarifair...
# 111          NaN                                                NaN
# 112         2.75  Le service hébergement a-t-il la possibilité d...
#
#      Unnamed: 9                Unnamed: 12                             Cycle
# ...

# %%
# Initialise une variable pour stocker la valeur de la sous-catégorie
sous_categories_actuelles = None
nouvelle_colonne_sous_categories = []

# Parcours les lignes du DataFrame
for index, row in df.iterrows():
    if  pd.isna(row[0]) and pd.isna(row[2]) and pd.isna(row[3]):
        # Si la colonne 6 est remplie et les colonnes 8 et 9 sont vides,
        # met la valeur de la colonne 2 dans "Sous-Catégories"
        sous_categories_actuelles = row[1]
    nouvelle_colonne_sous_categories.append(sous_categories_actuelles)

# Ajoute la nouvelle colonne "Sous-Catégories" au DataFrame
df['Sous-Catégories'] = nouvelle_colonne_sous_categories

df
# Out:
# C:\Users\cefim.D352004230014\AppData\Local\Temp\ipykernel_14272\600573465.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sous-Catégories'] = nouvelle_colonne_sous_categories
#      Pondération                                         Unnamed: 5  \
# 0            NaN                                                NaN
# 1            NaN                         1. Contrôle du Back office
# 2            NaN                                                NaN
# 3           3.00  Un contrôle du Bac sur un échantillon représen...
# 4            NaN                                                NaN
# ..           ...                                                ...
# ...

# %%
# Supprime la colonne 3 (en comptant à partir de 0)
df = df.drop(df.columns[2], axis=1)

# %%
df = df.dropna(subset=[df.columns[0]])

# %%
df['Thème'] = onglet_a_traiter

# %%
df
# Out:
#     N° Question  Pondération  \
# 3        Q-0001         3.00
# 6        Q-0002         4.00
# 7        Q-0003         3.00
# 8        Q-0004         3.00
# 9        Q-0005         3.00
# 10       Q-0006         4.00
# 12       Q-0007         2.00
# 14       Q-0008         3.00
# 18       Q-0009         3.00
# 20       Q-0010         3.00
# 22       Q-0011         3.00
# 24       Q-0012         3.00
# 28       Q-0013         4.00
# 33       Q-0014         4.00
# 35       Q-0015         4.50
# 37       Q-0016         4.50
# 39       Q-0017         4.50
# 41       Q-0018         4.50
# 43       Q-0019         4.00
# 45       Q-0020         4.00
# 48       Q-0021         4.00
# 50       Q-0022         4.00
# 53       Q-0023         4.00
# 55       Q-0024         4.00
# 57       Q-0025         4.00
# 59       Q-0026         4.00
# 63       Q-0027         4.00
# 65       Q-0028         3.00
# 67       Q-0029         3.00
# 71       Q-0030         3.00
# 72       Q-0031         2.50
# ...

# %%
# Supposons que df est votre DataFrame existant
df.columns = ['Pondération', 'Texte', 'Risques', 'Cycle','Sous-Catégories','Theme']

# %%
# Créez une nouvelle colonne 'N° Question' avec des valeurs de 'Q-0001' en incrémentant
df.insert(0, 'N° Question', ['Q-{:04d}'.format(i) for i in range(1, len(df) + 1)])

# Assurez-vous que la nouvelle colonne a été ajoutée en première position

# %%
# Réindexe le DataFrame
df = df.reset_index(drop=True)

# %%
df.to_csv('Fichier_Q.csv', index=False)

# %% [markdown]
# # 2°Onglet

# %%
import pandas as pd
import openpyxl



# Ouvrez le fichier Excel avec openpyxl
wb = openpyxl.load_workbook('Scoring Hôtel2.xlsx')

# Obtenez le nom du premier onglet
premier_onglet = wb.sheetnames[2]

# Fermez le fichier Excel
wb.close()

# Lisez le premier onglet avec pandas
df = pd.read_excel('Scoring Hôtel2.xlsx', sheet_name=premier_onglet, skiprows=7)

# Maintenant, 'df' contient les données du premier onglet en excluant les 7 premières lignes
onglet_a_traiter = premier_onglet
# Out:
# C:\Users\cefim.D352004230014\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2         0.70         0.0         0.0        2.10         NaN
# 3          NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN
# 6         0.70         0.0         0.0        2.10         NaN
# 7          NaN         NaN         NaN         NaN         NaN
# 8         0.70         0.0         0.0        2.10         NaN
# 9          NaN         NaN         NaN         NaN         NaN
# 10        0.70         0.0         0.0        2.10         NaN
# 11         NaN         NaN         NaN         NaN         NaN
# 12        0.70         0.0         0.0        2.10         NaN
# 13         NaN         NaN         NaN         NaN         NaN
# ...

# %%
# Réindexe le DataFrame
df = df.reset_index(drop=True)

# Enregistre les données mises à jour dans un nouveau fichier Excel
df.to_excel('Fichier_Question.xlsx', index=False)

# %%
import pandas as pd

# Charge le fichier CSV
df = pd.read_csv('Fichier_Q.csv')

# %%
df
# Out:
#     Pondération                                         Unnamed: 5  \
# 0          3.00  Un contrôle du Bac sur un échantillon représen...
# 1          4.00              - Existence de garanties de paiements
# 2          3.00                                 - Tarifs appliqués
# 3          3.00      - Présence des justificatifs Points de Ventes
# 4          3.00             - Visa du client sur les justificatifs
# 5          4.00  - Présence d'une fiche de police pour chaque c...
# 6          2.00  Le principe de note à la semaine est-il appliqué?
# 7          3.00  Un accord est-il formalisé par la Direction po...
# 8          3.00  Une limite de crédit a-t-elle été définie par ...
# 9          3.00  Un contrôle du dépassement de cette limite de ...
# 10         3.00  Les dépassements identifiés font-ils l'objet d...
# 11         3.00  L'ensemble des contrôles réalisés sur le bac e...
# 12         4.00  Les dépôts d'objets au coffre de l'hôtel ainsi...
# ...

# %%
# Initialisez une variable pour stocker la valeur de la sous-catégorie
sous_categories_actuelles = None

# Parcourez les lignes du DataFrame
for index, row in df.iterrows():
    if not pd.isna(row['Sous-Catégories']):
        # Si la colonne "Sous-Catégories" n'est pas NaN, mettez cette valeur dans la variable
        sous_categories_actuelles = row['Sous-Catégories']
    elif sous_categories_actuelles is not None:
        # Remplissez les lignes suivantes tant que la colonne "Cycle" reste la même
        df.at[index, 'Sous-Catégories'] = sous_categories_actuelles

# Enregistrez les données mises à jour dans un nouveau fichier CSV
#df.to_csv('nouveau_fichier_csv.csv', index=False)

# %%
df
# Out:
#     Pondération                                         Unnamed: 5  \
# 0          3.00  Un contrôle du Bac sur un échantillon représen...
# 1          4.00              - Existence de garanties de paiements
# 2          3.00                                 - Tarifs appliqués
# 3          3.00      - Présence des justificatifs Points de Ventes
# 4          3.00             - Visa du client sur les justificatifs
# 5          4.00  - Présence d'une fiche de police pour chaque c...
# 6          2.00  Le principe de note à la semaine est-il appliqué?
# 7          3.00  Un accord est-il formalisé par la Direction po...
# 8          3.00  Une limite de crédit a-t-elle été définie par ...
# 9          3.00  Un contrôle du dépassement de cette limite de ...
# 10         3.00  Les dépassements identifiés font-ils l'objet d...
# 11         3.00  L'ensemble des contrôles réalisés sur le bac e...
# 12         4.00  Les dépôts d'objets au coffre de l'hôtel ainsi...
# ...

# %% [markdown]
# ### Onglets complet
